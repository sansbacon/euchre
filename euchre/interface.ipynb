# %%
from importlib import reload
from euchre import play_euchre

# %reload_ext autoreload
# %autoreload 2

winning_score = 11

play_euchre(winning_score, verbose=True)
# Out:
# ----------------------------------------------------------------------------------------------------
# Dealer: Player2
# Player0: A♣ Q♥ K♥ J♠ J♣
# Player1: Q♠ Q♣ K♠ T♣ 7♦
# Player2: T♥ Q♦ 7♥ A♥ K♣
# Player3: A♠ 9♣ 7♠ 8♣ J♦
#
# Flipped: 7♣
# Player3 passes
# Player0 bids ♣ ALONE
#
# Player0: J♣ J♠ A♣ K♥ Q♥
# Player1: Q♣ T♣ K♠ Q♠ 7♦
# Player2: K♣ 7♣ A♥ T♥ 7♥
# Player3: 9♣ 8♣ A♠ J♦ 7♠
#
# Player3 leads: A♠ A♣ Q♠ Player0 takes (1-0)
# Player0 leads: J♣ T♣ 8♣ Player0 takes (2-0)
# Player0 leads: K♥ Q♣ 7♠ Player1 takes (2-1)
# Player1 leads: K♠ J♦ J♠ Player0 takes (3-1)
# Player0 leads: Q♥ 7♦ 9♣ Player3 takes (3-2)
#
# Team0 wins the round (1-0)
# ----------------------------------------------------------------------------------------------------
# Dealer: Player3
# Player0: J♦ K♣ J♥ T♥ K♥
# Player1: Q♠ 7♦ J♠ 9♣ Q♣
# Player2: T♣ J♣ 7♠ 7♣ T♠
# Player3: 8♠ A♦ Q♦ 8♥ A♣
#
# Flipped: Q♥
# Player0 bids ♥ ALONE
#
# Player0: J♥ J♦ K♥ T♥ K♣
# Player1: Q♠ Q♣ J♠ 9♣ 7♦
# Player2: J♣ T♣ T♠ 7♠ 7♣
# Player3: Q♥ 8♥ A♦ A♣ Q♦
#
# Player0 leads: J♥ 7♦ 8♥ Player0 takes (1-0)
# Player0 leads: J♦ 9♣ Q♥ Player0 takes (2-0)
# Player0 leads: K♥ J♠ Q♦ Player0 takes (3-0)
# Player0 leads: T♥ Q♠ A♣ Player0 takes (4-0)
# Player0 leads: K♣ Q♣ A♦ Player0 takes (5-0)
#
# Team0 wins the round (5-0)
# ----------------------------------------------------------------------------------------------------
# Dealer: Player0
# Player0: 8♦ A♠ T♣ Q♥ Q♣
# Player1: T♥ 7♠ K♦ 9♣ K♥
# Player2: A♥ A♦ 8♥ T♦ 7♣
# Player3: 7♥ J♣ 8♠ J♠ K♣
#
# Flipped: 8♣
# Player1 passes
# Player2 passes
# Player3 passes
# Player0 bids ♣
#
# Player0: Q♣ T♣ 8♣ A♠ Q♥
# Player1: 9♣ K♦ K♥ T♥ 7♠
# Player2: 7♣ A♥ A♦ T♦ 8♥
# Player3: J♣ J♠ K♣ 8♠ 7♥
#
# Player1 leads: K♥ A♥ 7♥ Q♥ Player2 takes (1-0)
# Player2 leads: 7♣ K♣ 8♣ 9♣ Player3 takes (1-1)
# Player3 leads: 8♠ A♠ 7♠ 8♥ Player0 takes (2-1)
# Player0 leads: Q♣ T♥ T♦ J♠ Player3 takes (2-2)
# Player3 leads: J♣ T♣ K♦ A♦ Player3 takes (2-3)
#
# Team1 wins the round (5-2)
# ----------------------------------------------------------------------------------------------------
# Dealer: Player1
# Player0: T♥ A♠ J♠ 8♦ Q♠
# Player1: 7♠ A♣ J♦ A♥ K♠
# Player2: 8♥ K♣ T♠ T♣ J♥
# Player3: 9♥ 8♠ 7♦ K♥ Q♣
#
# Flipped: T♦
# Player2 passes
# Player3 passes
# Player0 passes
# Player1 bids ♦ ALONE
#
# Player0: 8♦ A♠ Q♠ J♠ T♥
# Player1: J♦ T♦ A♣ A♥ K♠
# Player2: J♥ K♣ T♠ T♣ 8♥
# Player3: 7♦ K♥ Q♣ 9♥ 8♠
#
# Player2 leads: K♣ T♥ A♣ Player1 takes (0-1)
# Player1 leads: J♦ J♥ 8♦ Player1 takes (0-2)
# Player1 leads: A♥ 8♥ J♠ Player1 takes (0-3)
# Player1 leads: T♦ T♣ Q♠ Player1 takes (0-4)
# Player1 leads: K♠ T♠ A♠ Player0 takes (1-4)
#
# Team1 wins the round (5-3)
# ----------------------------------------------------------------------------------------------------
# Dealer: Player2
# Player0: K♦ T♣ 9♦ 7♦ 9♥
# Player1: 9♣ T♦ 7♣ T♠ 8♦
# Player2: 7♥ A♥ J♣ A♦ 8♥
# Player3: A♣ J♠ Q♣ K♥ Q♦
#
# Flipped: 8♠
# Player3 passes
# Player0 passes
# Player1 passes
# Player2 bids ♠
#
# Player0: K♦ T♣ 9♦ 9♥ 7♦
# Player1: T♠ T♦ 9♣ 8♦ 7♣
# Player2: J♣ 8♠ A♥ A♦ 8♥
# Player3: J♠ A♣ K♥ Q♣ Q♦
#
# Player3 leads: A♣ T♣ 7♣ 8♥ Player3 takes (0-1)
# Player3 leads: K♥ 9♥ 9♣ A♥ Player2 takes (1-1)
# Player2 leads: J♣ J♠ 7♦ T♠ Player3 takes (1-2)
# Player3 leads: Q♦ K♦ 8♦ A♦ Player2 takes (2-2)
# Player2 leads: 8♠ Q♣ 9♦ T♦ Player2 takes (3-2)
#
# Team0 wins the round (6-3)
# ----------------------------------------------------------------------------------------------------
# Dealer: Player3
# Player0: 8♥ J♣ T♣ 7♣ A♥
# Player1: J♠ Q♥ 7♥ 9♣ A♦
# Player2: K♣ 8♣ A♠ K♠ J♥
# Player3: Q♠ 7♠ T♠ 8♦ T♦
#
# Flipped: Q♦
# Player0 passes
# Player1 passes
# Player2 passes
# Player3 bids ♦
#
# Player0: A♥ J♣ T♣ 8♥ 7♣
# Player1: A♦ Q♥ J♠ 9♣ 7♥
# Player2: J♥ A♠ K♣ K♠ 8♣
# Player3: Q♦ T♦ 8♦ Q♠ T♠
#
# Player0 leads: A♥ 7♥ 8♣ 8♦ Player3 takes (0-1)
# Player3 leads: Q♦ 7♣ A♦ J♥ Player2 takes (1-1)
# Player2 leads: A♠ T♠ 8♥ J♠ Player2 takes (2-1)
# Player2 leads: K♣ T♦ T♣ 9♣ Player3 takes (2-2)
# Player3 leads: Q♠ J♣ Q♥ K♠ Player2 takes (3-2)
#
# Team0 wins the round (8-3)
# ----------------------------------------------------------------------------------------------------
# Dealer: Player0
# Player0: J♦ T♣ Q♦ A♦ 7♦
# Player1: T♠ Q♠ T♥ J♥ 7♣
# Player2: 9♥ 9♦ 8♦ Q♣ 8♠
# Player3: K♣ A♣ K♥ 9♠ 9♣
#
# Flipped: 8♣
# Player1 passes
# Player2 passes
# Player3 passes
# Player0 passes
# Player1 bids ♥
#
# Player0: J♦ A♦ Q♦ T♣ 7♦
# Player1: J♥ T♥ Q♠ T♠ 7♣
# Player2: 9♥ Q♣ 9♦ 8♦ 8♠
# Player3: K♥ A♣ K♣ 9♠ 9♣
#
# Player1 leads: J♥ 9♥ K♥ J♦ Player1 takes (0-1)
# Player1 leads: Q♠ 8♠ 9♠ 7♦ Player1 takes (0-2)
# Player1 leads: T♠ 8♦ 9♣ T♣ Player1 takes (0-3)
# Player1 leads: T♥ 9♦ K♣ Q♦ Player1 takes (0-4)
# Player1 leads: 7♣ Q♣ A♣ A♦ Player3 takes (0-5)
#
# Team1 wins the round (8-5)
# ----------------------------------------------------------------------------------------------------
# Dealer: Player1
# Player0: 7♦ J♠ 8♣ A♠ T♦
# Player1: 7♠ Q♥ 7♣ 8♠ 9♦
# Player2: T♥ 8♦ Q♦ 7♥ A♦
# Player3: J♦ K♥ 9♥ 8♥ 9♣
#
# Flipped: A♣
# Player2 passes
# Player3 passes
# Player0 passes
# Player1 passes
# Player2 bids ♦
#
# Player0: T♦ 7♦ A♠ J♠ 8♣
# Player1: 9♦ Q♥ 8♠ 7♠ 7♣
# Player2: A♦ Q♦ 8♦ T♥ 7♥
# Player3: J♦ K♥ 9♥ 9♣ 8♥
#
# Player2 leads: A♦ J♦ 7♦ 9♦ Player3 takes (0-1)
# Player3 leads: K♥ T♦ Q♥ 7♥ Player0 takes (1-1)
# Player0 leads: A♠ 7♠ T♥ 8♥ Player0 takes (2-1)
# Player0 leads: J♠ 8♠ 8♦ 9♥ Player2 takes (3-1)
# Player2 leads: Q♦ 9♣ 8♣ 7♣ Player2 takes (4-1)
#
# Team0 wins the round (9-5)
# ----------------------------------------------------------------------------------------------------
# Dealer: Player2
# Player0: 7♣ 7♠ J♦ 8♣ 8♦
# Player1: Q♠ Q♥ K♦ K♣ T♦
# Player2: T♣ 8♥ T♠ J♥ A♥
# Player3: 9♦ J♠ A♠ 7♦ 9♣
#
# Flipped: T♥
# Player3 passes
# Player0 passes
# Player1 passes
# Player2 bids ♥ ALONE
#
# Player0: J♦ 8♣ 8♦ 7♣ 7♠
# Player1: Q♥ K♦ K♣ Q♠ T♦
# Player2: J♥ A♥ T♥ 8♥ T♠
# Player3: A♠ J♠ 9♦ 9♣ 7♦
#
# Player3 leads: A♠ Q♠ T♠ Player3 takes (0-1)
# Player3 leads: J♠ K♣ 8♥ Player2 takes (1-1)
# Player2 leads: J♥ 7♦ Q♥ Player2 takes (2-1)
# Player2 leads: A♥ 9♦ T♦ Player2 takes (3-1)
# Player2 leads: T♥ 9♣ K♦ Player2 takes (4-1)
#
# Team0 wins the round (10-5)
# ----------------------------------------------------------------------------------------------------
# Dealer: Player3
# Player0: A♦ T♥ J♦ K♥ 9♥
# Player1: Q♣ 8♦ 9♦ 8♠ J♥
# Player2: 9♣ 8♥ K♠ 7♠ 7♥
# Player3: 7♣ Q♦ 7♦ 9♠ K♦
#
# Flipped: A♣
# Player0 passes
# Player1 passes
# Player2 passes
# Player3 passes
# Player0 bids ♥ ALONE
#
# Player0: J♦ K♥ T♥ 9♥ A♦
# Player1: J♥ Q♣ 9♦ 8♦ 8♠
# Player2: 8♥ 7♥ K♠ 9♣ 7♠
# Player3: K♦ Q♦ 9♠ 7♣ 7♦
#
# Player0 leads: J♦ J♥ 7♣ Player1 takes (0-1)
# Player1 leads: Q♣ 7♦ 9♥ Player0 takes (1-1)
# Player0 leads: K♥ 8♠ 9♠ Player0 takes (2-1)
# Player0 leads: T♥ 8♦ Q♦ Player0 takes (3-1)
# Player0 leads: A♦ 9♦ K♦ Player0 takes (4-1)
#
# Team0 wins the round (11-5)
# ----------------------------------------------------------------------------------------------------
# Team0 wins!
